# %% [markdown]
# <a href="https://colab.research.google.com/github/Jyoti-Yadav2/R-for-bioinformatics/blob/main/Introduction_to_R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Introduction to R
# Change runtime to R

# %%
#Install R base
#Configure rpy2

# %%
print("R base and rpy2 installed and configured")
# Out:
# [1] "R base and rpy2 installed and configured"

# %%
install.packages("BiocManager")
BiocManager::install()
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.rstudio.com
#
# Bioconductor version 3.23 (BiocManager 1.30.27), R 4.6.0 (2026-04-24)
#
# Old packages: 'callr', 'dbplyr', 'httr2', 'openssl', 'pak', 'pkgload',
#   'rstudioapi', 'selectr', 'sessioninfo', 'shiny', 'tinytex', 'withr', 'xfun',
#   'xml2', 'xtable', 'zip'

# %% [markdown]
# #here x is scalar variable
# scalar, vector, matrix, dataframes, tables and lists are different types of objects in R

# %%
2+3
x <- 10-3
x
# Out:
# [1] 5
# [1] 7

# %% [markdown]
# while scalar has just one element, a vector consists of several elements. these elements are of same typr(eg. numeric or characters).
# c() is combine function, [] isindex to extract value of element in vector

# %%
myvector <- c(8, 9, 10, 15)
myvector
myvector[4]
# Out:
# [1]  8  9 10 15
# [1] 15

# %%
mylist <- list(name="jenna", myvector)
mylist
# Out:
# $name
# [1] "jenna"
#
# [[2]]
# [1]  8  9 10 15

# %%
mylist[[2]]
attributes(mylist)
# Out:
# [1]  8  9 10 15
# $names
# [1] "name" ""

# %%
myDNA <- c("A", "T", "G", "C", "T", "T", "A", "G", "C", "C", "C", "T", "T", "A", "A")
table(myDNA)
myDNA[[4]]
# Out:
# myDNA
# A C G T
# 4 4 2 5
# [1] "C"

# %%
help.search("deviation")

# %%
RSiteSearch("deviation")
# Out:
# A search query has been submitted to https://search.r-project.org
# The results page should open in your browser shortly

# %%
mean(myvector)
# Out:
# [1] 10.5

# %% [markdown]
# Functions in R usually require arguments,which are input variables(i.e. objects). built-in R functions such as mean(), lengtg(), print(), plot(), etc. return() statement returns the calculated value.

# %%
myfunction <- function(x) { return(20 + (x*x)) }
myfunction(10)
myfunction(15)
# Out:
# [1] 120
# [1] 245

# %% [markdown]
# to quit R, type:

# %%
q()
